# %%
execfile('/home/xiaodongli/software/pythonlib/stdA.py')
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = np.loadtxt('./AP_main_smallcov.txt')
X,Y,Z= XYZfromdata(data)
fig, ax = figax()
ax.plot(X,Y,label='sys cored')
ax.plot(X,Z,label='uncored')
ax.legend(fontsize=18)

# %%
data = np.loadtxt('./AP_main_bigcov.txt')
X,Y,Z= XYZfromdata(data)
fig, ax = figax()
ax.plot(X,Y,label='sys cored')
#ax.plot(X,Z,label='uncored')
ax.legend(fontsize=18)

# %%
data = np.loadtxt('./AP_main_bigcov.txt')
X,Y,Z= XYZfromdata(data)
fig, ax = figax()
ax.plot(X,Y,label='sys cored')
#ax.plot(X,Z,label='uncored')
ax.legend(fontsize=18)

# %%
data = np.loadtxt('./AP_main_bigcov.txt')
X,Y,Z= XYZfromdata(data)
fig, ax = figax()
ax.plot(X,Y,label='sys cored')
ax.plot(X,Z,label='uncored')
ax.legend(fontsize=18)

# %%
data = np.loadtxt('./AP_main_bigcov.txt')
X,Y,Z= XYZfromdata(data)
fig, ax = figax()
ax.plot(X,Y,label='sys cored')
ax.plot(X,Z,label='uncored')
ax.legend(fontsize=18)

# %%
data = np.loadtxt('./AP_main_bigcov.txt')
X,Y,Z= XYZfromdata(data)
fig, ax = figax()
ax.plot(X,Y,label='sys cored')
ax.plot(X,Z,label='uncored')
ax.legend(fontsize=18)

# %%
data = np.loadtxt('./AP_main_bigcov.txt')
X,Y,Z= XYZfromdata(data)
fig, ax = figax()
ax.plot(X,Y,label='sys cored')
ax.plot(X,Z,label='uncored')
ax.legend(fontsize=18)
